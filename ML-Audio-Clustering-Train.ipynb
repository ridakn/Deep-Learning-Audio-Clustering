# %% [markdown]
# # Imports

# %%
import cv2
import csv
import os
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Conv2D, Conv2DTranspose
from keras.layers import Input, UpSampling2D, MaxPooling2D
from keras.models import Model
from keras.models import model_from_json
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from sklearn.cluster import KMeans
import pylab
import librosa
import librosa.display
import matplotlib
# %matplotlib inline

# %% [markdown]
# #### Set Root Path to Your Directory

# %%
ROOT_PATH = "/Users/ridakhan/Desktop/PR3/"
DATA_PATH = ROOT_PATH + "dataset/"
MEL_PATH = ROOT_PATH + 'audioimages/melspec/'
WEIGHTS_PATH = ROOT_PATH + "Models/"
RESULTS_PATH = ROOT_PATH + "Results/"

# %% [markdown]
# #### Function to calculate mean squared error for evaluation purposes.

# %%
def mse(imageA, imageB):

    err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
    err /= float(imageA.shape[0] * imageA.shape[1])

    return err

# %% [markdown]
# # Dataset

# %% [markdown]
# #### Creating the mel spectrograms and saving them in directory

# %% [markdown]
# Song_path: path to the audio files
#
# Save_path: path to save the spectrograms

# %%
def create_mel_spec(song_path, save_path):
    for songname in os.listdir(song_path):

        audio_path= DATA_PATH + songname #+ '.wav' #location
        sig, fs = librosa.load(audio_path)   
        pylab.axis('off') # no axis
        pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
        S = librosa.feature.melspectrogram(y=sig, sr=fs)
        librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
        pylab.axis('off')
        pylab.margins(0,0)
        pylab.gca().xaxis.set_major_locator(plt.NullLocator())
        pylab.gca().yaxis.set_major_locator(plt.NullLocator())
        name = songname.split(".")[0]
        pylab.savefig(save_path + name + ".png", bbox_inches=None, pad_inches=0, aspect = 'auto')
        pylab.close()
    print("Saved all images at ", save_path)

# %%
create_mel_spec(DATA_PATH, MEL_PATH)

# %% [markdown]
# #### Loading the images into an array

# %%
def load_imgs(path):
    dataset = []
    for i in range(1, 672):
        imgname = str(i) + ".png"
        img = cv2.imread(path + imgname, 1)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        if img is not None:
            dataset.append(img)
    dataset = np.array(dataset)
    return dataset

# %%
data_set = load_imgs(MEL_PATH)
print(data_set.shape)
# Out:
# (671, 288, 432, 3)

# %% [markdown]
# Sample Frame

# %%
plt.imshow(data_set[0])
plt.axis("off")
plt.show()

# %% [markdown]
# #### Splitting the images into blocks of size (144, 144, 3) to use as input to the model

# %%
# Define the window size
block_size = 144

w, h = data_set[0].shape[0], data_set[0].shape[1]
block_data_set = []

for img in data_set:
    for r in range(0, w, block_size): # 144
        for c in range(0, h, block_size): # 288
            block_data_set.append(img[r:r+block_size,c:c+block_size]) 

block_data_set = np.array(block_data_set)
print(block_data_set.shape)
# Out:
# (4026, 144, 144, 3)

# %% [markdown]
# # Training

# %%
MODEL_INDEX = 60
modelname = "PR3_" + str(MODEL_INDEX)
print(modelname)

input_img = Input(shape=(144, 144, 3))

x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(1, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(16, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(3, (3, 3), activation='relu', padding='same')(x)

extraction_model = Model(input_img, decoded)
extraction_model.compile(optimizer='adam', loss='mse')

extraction_model.summary()
# Out:
# PR3_60
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 144, 144, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 144, 144, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 72, 72, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 36, 36, 16)        4624
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 18, 18, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 18, 18, 1)         145
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 9, 9, 1)           0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 9, 9, 16)          160
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 18, 18, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 18, 18, 16)        2320
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 36, 36, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 36, 36, 32)        4640
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 72, 72, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 144, 144, 32)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 144, 144, 3)       867
# =================================================================
# Total params: 32,148
# Trainable params: 32,148
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_json = extraction_model.to_json()

with open(ROOT_PATH + 'Models/' + modelname + '.json', "w") as json_file:
    json_file.write(model_json)

earlystop = EarlyStopping(monitor='loss', 
                          min_delta=0.09, 
                          patience=20, 
                          verbose=2, 
                          mode='auto', 
                          baseline=None, 
                          restore_best_weights=True)  

checkpointer = ModelCheckpoint(filepath = ROOT_PATH + 'Models/' + modelname + '.hdf5', 
                               monitor='loss',
                               save_best_only=True)

callbacks_list = [earlystop, checkpointer]


extraction_model.fit(block_data_set, block_data_set,
                     batch_size=4, 
                     epochs=500, 
                     callbacks=callbacks_list)
# Out:
# PR3_60
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 144, 144, 3)]     0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 144, 144, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 72, 72, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 72, 72, 32)        9248
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 36, 36, 16)        4624
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 18, 18, 16)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 18, 18, 1)         145
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 9, 9, 1)           0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 9, 9, 16)          160
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 18, 18, 16)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 18, 18, 16)        2320
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 36, 36, 16)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 36, 36, 32)        4640
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 72, 72, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 72, 72, 32)        9248
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 144, 144, 32)      0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 144, 144, 3)       867
# =================================================================
# Total params: 32,148
# Trainable params: 32,148
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 336/336 [==============================] - 1s 4ms/step - loss: 969.6721
# Epoch 2/500
# 336/336 [==============================] - 1s 4ms/step - loss: 565.6660
# Epoch 3/500
# 336/336 [==============================] - 1s 4ms/step - loss: 503.3285
# Epoch 4/500
# 336/336 [==============================] - 1s 3ms/step - loss: 458.1660
# Epoch 5/500
# 336/336 [==============================] - 1s 3ms/step - loss: 458.5461
# Epoch 6/500
# 336/336 [==============================] - 1s 4ms/step - loss: 420.0312
# Epoch 7/500
# 336/336 [==============================] - 1s 4ms/step - loss: 415.1882
# Epoch 8/500
# 336/336 [==============================] - 1s 4ms/step - loss: 408.9406
# Epoch 9/500
# 336/336 [==============================] - 1s 3ms/step - loss: 416.8250
# Epoch 10/500
# 336/336 [==============================] - 1s 4ms/step - loss: 401.1034
# Epoch 11/500
# 336/336 [==============================] - 1s 3ms/step - loss: 407.3689
# Epoch 12/500
# 336/336 [==============================] - 1s 4ms/step - loss: 378.3725
# Epoch 13/500
# 336/336 [==============================] - 1s 3ms/step - loss: 381.7477
# Epoch 14/500
# 336/336 [==============================] - 1s 4ms/step - loss: 373.1960
# Epoch 15/500
# 336/336 [==============================] - 1s 3ms/step - loss: 366.4481
# Epoch 16/500
# 336/336 [==============================] - 1s 4ms/step - loss: 355.3190
# Epoch 17/500
# 336/336 [==============================] - 1s 4ms/step - loss: 339.5967
# Epoch 18/500
# 336/336 [==============================] - 1s 4ms/step - loss: 334.0274
# Epoch 19/500
# 336/336 [==============================] - 1s 4ms/step - loss: 323.0029
# Epoch 20/500
# 336/336 [==============================] - 1s 4ms/step - loss: 312.8232
# Epoch 21/500
# 336/336 [==============================] - 1s 3ms/step - loss: 313.5172
# Epoch 22/500
# 336/336 [==============================] - 1s 4ms/step - loss: 311.6402
# Epoch 23/500
# 336/336 [==============================] - 1s 3ms/step - loss: 313.6391
# Epoch 24/500
# 336/336 [==============================] - 1s 4ms/step - loss: 308.8254
# Epoch 25/500
# 336/336 [==============================] - 1s 4ms/step - loss: 298.7511
# Epoch 26/500
# 336/336 [==============================] - 1s 3ms/step - loss: 304.3110
# Epoch 27/500
# 336/336 [==============================] - 1s 3ms/step - loss: 301.0438
# Epoch 28/500
# 336/336 [==============================] - 1s 4ms/step - loss: 297.5313
# Epoch 29/500
# 336/336 [==============================] - 1s 3ms/step - loss: 294.2930
# Epoch 30/500
# 336/336 [==============================] - 1s 3ms/step - loss: 298.0006
# Epoch 31/500
# 336/336 [==============================] - 1s 4ms/step - loss: 289.4968
# Epoch 32/500
# 336/336 [==============================] - 1s 4ms/step - loss: 286.1351
# Epoch 33/500
# 336/336 [==============================] - 1s 4ms/step - loss: 283.0552
# Epoch 34/500
# 336/336 [==============================] - 1s 3ms/step - loss: 283.1088
# Epoch 35/500
# 336/336 [==============================] - 1s 4ms/step - loss: 281.2906
# Epoch 36/500
# 336/336 [==============================] - 1s 3ms/step - loss: 282.1829
# Epoch 37/500
# 336/336 [==============================] - 1s 3ms/step - loss: 279.1983
# Epoch 38/500
# 336/336 [==============================] - 1s 3ms/step - loss: 287.5917
# Epoch 39/500
# 336/336 [==============================] - 1s 4ms/step - loss: 272.9728
# Epoch 40/500
# 336/336 [==============================] - 1s 3ms/step - loss: 274.2317
# Epoch 41/500
# 336/336 [==============================] - 1s 3ms/step - loss: 291.5550
# Epoch 42/500
# 336/336 [==============================] - 1s 3ms/step - loss: 275.1032
# Epoch 43/500
# 336/336 [==============================] - 1s 3ms/step - loss: 275.8950
# Epoch 44/500
# 336/336 [==============================] - 1s 3ms/step - loss: 273.6194
# Epoch 45/500
# 336/336 [==============================] - 1s 3ms/step - loss: 275.0654
# Epoch 46/500
# 336/336 [==============================] - 1s 4ms/step - loss: 269.8291
# Epoch 47/500
# 336/336 [==============================] - 1s 3ms/step - loss: 271.3097
# Epoch 48/500
# 336/336 [==============================] - 1s 3ms/step - loss: 271.6294
# Epoch 49/500
# 336/336 [==============================] - 1s 3ms/step - loss: 271.3098
# Epoch 50/500
# 336/336 [==============================] - 1s 4ms/step - loss: 266.8923
# Epoch 51/500
# 336/336 [==============================] - 1s 3ms/step - loss: 273.4346
# Epoch 52/500
# 336/336 [==============================] - 1s 3ms/step - loss: 267.8590
# Epoch 53/500
# 336/336 [==============================] - 1s 3ms/step - loss: 267.5688
# Epoch 54/500
# 336/336 [==============================] - 1s 3ms/step - loss: 270.0528
# Epoch 55/500
# 336/336 [==============================] - 1s 3ms/step - loss: 272.7704
# Epoch 56/500
# 336/336 [==============================] - 1s 4ms/step - loss: 265.1891
# Epoch 57/500
# 336/336 [==============================] - 1s 3ms/step - loss: 267.2220
# Epoch 58/500
# 336/336 [==============================] - 1s 3ms/step - loss: 265.7175
# Epoch 59/500
# 336/336 [==============================] - 1s 3ms/step - loss: 265.6469
# Epoch 60/500
# 336/336 [==============================] - 1s 3ms/step - loss: 265.2745
# Epoch 61/500
# 336/336 [==============================] - 1s 3ms/step - loss: 267.9415
# Epoch 62/500
# 336/336 [==============================] - 1s 3ms/step - loss: 269.2947
# Epoch 63/500
# 336/336 [==============================] - 1s 3ms/step - loss: 265.5148
# Epoch 64/500
# 336/336 [==============================] - 1s 4ms/step - loss: 264.0240
# Epoch 65/500
# 336/336 [==============================] - 1s 3ms/step - loss: 265.3611
# Epoch 66/500
# 336/336 [==============================] - 1s 4ms/step - loss: 260.5739
# Epoch 67/500
# 336/336 [==============================] - 1s 3ms/step - loss: 260.9236
# Epoch 68/500
# 336/336 [==============================] - 1s 3ms/step - loss: 267.2196
# Epoch 69/500
# 336/336 [==============================] - 1s 3ms/step - loss: 265.3335
# Epoch 70/500
# 336/336 [==============================] - 1s 3ms/step - loss: 262.8551
# Epoch 71/500
# 336/336 [==============================] - 1s 3ms/step - loss: 263.7414
# Epoch 72/500
# 336/336 [==============================] - 1s 4ms/step - loss: 260.1729
# Epoch 73/500
# 336/336 [==============================] - 1s 3ms/step - loss: 263.3624
# Epoch 74/500
# 336/336 [==============================] - 1s 4ms/step - loss: 259.9866
# Epoch 75/500
# 336/336 [==============================] - 1s 3ms/step - loss: 261.6360
# Epoch 76/500
# 336/336 [==============================] - 1s 4ms/step - loss: 259.4509
# Epoch 77/500
# 336/336 [==============================] - 1s 4ms/step - loss: 263.7151
# Epoch 78/500
# 336/336 [==============================] - 1s 3ms/step - loss: 257.9455
# Epoch 79/500
# 336/336 [==============================] - 1s 3ms/step - loss: 260.8941
# Epoch 80/500
# 336/336 [==============================] - 1s 4ms/step - loss: 256.0585
# Epoch 81/500
# 336/336 [==============================] - 1s 3ms/step - loss: 264.3340
# Epoch 82/500
# 336/336 [==============================] - 1s 3ms/step - loss: 258.4882
# Epoch 83/500
# 336/336 [==============================] - 1s 3ms/step - loss: 256.7939
# Epoch 84/500
# 336/336 [==============================] - 1s 3ms/step - loss: 259.0901
# Epoch 85/500
# 336/336 [==============================] - 1s 3ms/step - loss: 264.2135
# Epoch 86/500
# 336/336 [==============================] - 1s 3ms/step - loss: 257.2832
# Epoch 87/500
# 336/336 [==============================] - 1s 3ms/step - loss: 256.7628
# Epoch 88/500
# 336/336 [==============================] - 1s 3ms/step - loss: 258.5800
# Epoch 89/500
# 336/336 [==============================] - 1s 4ms/step - loss: 254.9159
# Epoch 90/500
# 336/336 [==============================] - 1s 4ms/step - loss: 254.7529
# Epoch 91/500
# 336/336 [==============================] - 1s 3ms/step - loss: 258.3952
# Epoch 92/500
# 336/336 [==============================] - 1s 3ms/step - loss: 256.7316
# Epoch 93/500
# 336/336 [==============================] - 1s 3ms/step - loss: 257.6335
# Epoch 94/500
# 336/336 [==============================] - 1s 3ms/step - loss: 257.5360
# Epoch 95/500
# 336/336 [==============================] - 1s 4ms/step - loss: 253.4142
# Epoch 96/500
# 336/336 [==============================] - 1s 3ms/step - loss: 255.0045
# Epoch 97/500
# 336/336 [==============================] - 1s 3ms/step - loss: 253.9819
# Epoch 98/500
# 336/336 [==============================] - 1s 3ms/step - loss: 254.3834
# Epoch 99/500
# 336/336 [==============================] - 1s 4ms/step - loss: 258.9078
# Epoch 100/500
# 336/336 [==============================] - 1s 3ms/step - loss: 254.3526
# Epoch 101/500
# 336/336 [==============================] - 1s 3ms/step - loss: 255.6107
# Epoch 102/500
# 336/336 [==============================] - 1s 4ms/step - loss: 252.9263
# Epoch 103/500
# 336/336 [==============================] - 1s 3ms/step - loss: 254.6637
# Epoch 104/500
# 336/336 [==============================] - 1s 3ms/step - loss: 253.0140
# Epoch 105/500
# 336/336 [==============================] - 1s 3ms/step - loss: 255.1613
# Epoch 106/500
# 336/336 [==============================] - 1s 3ms/step - loss: 255.9498
# Epoch 107/500
# 336/336 [==============================] - 1s 3ms/step - loss: 254.2308
# Epoch 108/500
# 336/336 [==============================] - 1s 4ms/step - loss: 251.1354
# Epoch 109/500
# 336/336 [==============================] - 1s 3ms/step - loss: 251.9611
# Epoch 110/500
# 336/336 [==============================] - 1s 3ms/step - loss: 255.1731
# Epoch 111/500
# 336/336 [==============================] - 1s 3ms/step - loss: 253.0172
# Epoch 112/500
# 336/336 [==============================] - 1s 4ms/step - loss: 250.4789
# Epoch 113/500
# 336/336 [==============================] - 1s 3ms/step - loss: 253.3048
# Epoch 114/500
# 336/336 [==============================] - 1s 3ms/step - loss: 254.0508
# Epoch 115/500
# 336/336 [==============================] - 1s 3ms/step - loss: 254.4327
# Epoch 116/500
# 336/336 [==============================] - 1s 3ms/step - loss: 251.5789
# Epoch 117/500
# 336/336 [==============================] - 1s 3ms/step - loss: 252.3724
# Epoch 118/500
# 336/336 [==============================] - 1s 4ms/step - loss: 250.0203
# Epoch 119/500
# 336/336 [==============================] - 1s 3ms/step - loss: 251.5867
# Epoch 120/500
# 336/336 [==============================] - 1s 3ms/step - loss: 253.5316
# Epoch 121/500
# 336/336 [==============================] - 1s 3ms/step - loss: 250.5659
# Epoch 122/500
# 336/336 [==============================] - 1s 4ms/step - loss: 249.8738
# Epoch 123/500
# 336/336 [==============================] - 1s 4ms/step - loss: 249.5955
# Epoch 124/500
# 336/336 [==============================] - 1s 3ms/step - loss: 250.0762
# Epoch 125/500
# 336/336 [==============================] - 1s 3ms/step - loss: 252.0884
# Epoch 126/500
# 336/336 [==============================] - 1s 3ms/step - loss: 250.4843
# Epoch 127/500
# 336/336 [==============================] - 1s 4ms/step - loss: 249.1406
# Epoch 128/500
# 336/336 [==============================] - 1s 4ms/step - loss: 249.0301
# Epoch 129/500
# 336/336 [==============================] - 1s 3ms/step - loss: 247.1101
# Epoch 130/500
# 336/336 [==============================] - 1s 3ms/step - loss: 247.7309
# Epoch 131/500
# 336/336 [==============================] - 1s 3ms/step - loss: 250.5032
# Epoch 132/500
# 336/336 [==============================] - 1s 3ms/step - loss: 251.0792
# Epoch 133/500
# 336/336 [==============================] - 1s 3ms/step - loss: 252.4151
# Epoch 134/500
# 336/336 [==============================] - 1s 3ms/step - loss: 247.6461
# Epoch 135/500
# 336/336 [==============================] - 1s 3ms/step - loss: 250.4793
# Epoch 136/500
# 336/336 [==============================] - 1s 3ms/step - loss: 248.6740
# Epoch 137/500
# 336/336 [==============================] - 1s 3ms/step - loss: 247.1644
# Epoch 138/500
# 336/336 [==============================] - 1s 3ms/step - loss: 248.0695
# Epoch 139/500
# 336/336 [==============================] - 1s 3ms/step - loss: 248.7240
# Epoch 140/500
# 336/336 [==============================] - 1s 3ms/step - loss: 249.1341
# Epoch 141/500
# 336/336 [==============================] - 1s 3ms/step - loss: 249.1618
# Epoch 142/500
# 336/336 [==============================] - 1s 3ms/step - loss: 248.6900
# Epoch 143/500
# 336/336 [==============================] - 1s 3ms/step - loss: 248.6023
# Epoch 144/500
# 336/336 [==============================] - 1s 3ms/step - loss: 255.9443
# Epoch 145/500
# 336/336 [==============================] - 1s 3ms/step - loss: 248.0437
# Epoch 146/500
# 336/336 [==============================] - 1s 4ms/step - loss: 246.5400
# Epoch 147/500
# 336/336 [==============================] - 1s 4ms/step - loss: 245.7702
# Epoch 148/500
# 336/336 [==============================] - 1s 3ms/step - loss: 247.9877
# Epoch 149/500
# 336/336 [==============================] - 1s 4ms/step - loss: 245.5012
# Epoch 150/500
# 336/336 [==============================] - 1s 3ms/step - loss: 248.5879
# Epoch 151/500
# 336/336 [==============================] - 1s 3ms/step - loss: 249.8610
# Epoch 152/500
# 336/336 [==============================] - 1s 3ms/step - loss: 246.3896
# Epoch 153/500
# 336/336 [==============================] - 1s 3ms/step - loss: 247.1502
# Epoch 154/500
# 336/336 [==============================] - 1s 3ms/step - loss: 249.4695
# Epoch 155/500
# 336/336 [==============================] - 1s 3ms/step - loss: 245.5445
# Epoch 156/500
# 336/336 [==============================] - 1s 4ms/step - loss: 245.3395
# Epoch 157/500
# 336/336 [==============================] - 1s 3ms/step - loss: 246.8200
# Epoch 158/500
# 336/336 [==============================] - 1s 4ms/step - loss: 244.8130
# Epoch 159/500
# 336/336 [==============================] - 1s 3ms/step - loss: 246.9720
# Epoch 160/500
# 336/336 [==============================] - 1s 3ms/step - loss: 246.7967
# Epoch 161/500
# 336/336 [==============================] - 1s 4ms/step - loss: 244.6973
# Epoch 162/500
# 336/336 [==============================] - 1s 3ms/step - loss: 247.4181
# Epoch 163/500
# 336/336 [==============================] - 1s 3ms/step - loss: 244.7034
# Epoch 164/500
# 336/336 [==============================] - 1s 3ms/step - loss: 245.5902
# Epoch 165/500
# 336/336 [==============================] - 1s 3ms/step - loss: 245.5496
# Epoch 166/500
# 336/336 [==============================] - 1s 3ms/step - loss: 246.7022
# Epoch 167/500
# 336/336 [==============================] - 1s 4ms/step - loss: 243.4110
# Epoch 168/500
# 336/336 [==============================] - 1s 3ms/step - loss: 246.3056
# Epoch 169/500
# 336/336 [==============================] - 1s 3ms/step - loss: 243.8266
# Epoch 170/500
# 336/336 [==============================] - 1s 3ms/step - loss: 243.6567
# Epoch 171/500
# 336/336 [==============================] - 1s 3ms/step - loss: 246.7129
# Epoch 172/500
# 336/336 [==============================] - 1s 3ms/step - loss: 243.8829
# Epoch 173/500
# 336/336 [==============================] - 1s 3ms/step - loss: 245.7393
# Epoch 174/500
# 336/336 [==============================] - 1s 3ms/step - loss: 244.7716
# Epoch 175/500
# 336/336 [==============================] - 1s 3ms/step - loss: 247.8971
# Epoch 176/500
# 336/336 [==============================] - 1s 3ms/step - loss: 244.7583
# Epoch 177/500
# 336/336 [==============================] - 1s 3ms/step - loss: 241.5911
# Epoch 178/500
# 336/336 [==============================] - 1s 3ms/step - loss: 245.4186
# Epoch 179/500
# 336/336 [==============================] - 1s 3ms/step - loss: 243.0693
# Epoch 180/500
# 336/336 [==============================] - 1s 3ms/step - loss: 243.9389
# Epoch 181/500
# 336/336 [==============================] - 1s 3ms/step - loss: 243.3615
# Epoch 182/500
# 336/336 [==============================] - 1s 4ms/step - loss: 241.6456
# Epoch 183/500
# 336/336 [==============================] - 1s 4ms/step - loss: 241.5433
# Epoch 184/500
# 336/336 [==============================] - 1s 3ms/step - loss: 243.3721
# Epoch 185/500
# 336/336 [==============================] - 1s 3ms/step - loss: 245.7297
# Epoch 186/500
# 336/336 [==============================] - 1s 3ms/step - loss: 243.9993
# Epoch 187/500
# 336/336 [==============================] - 1s 3ms/step - loss: 241.9610
# Epoch 188/500
# 336/336 [==============================] - 1s 3ms/step - loss: 244.8376
# Epoch 189/500
# 336/336 [==============================] - 1s 3ms/step - loss: 244.3368
# Epoch 190/500
# 336/336 [==============================] - 1s 4ms/step - loss: 240.8236
# Epoch 191/500
# 336/336 [==============================] - 1s 3ms/step - loss: 244.0897
# Epoch 192/500
# 336/336 [==============================] - 1s 3ms/step - loss: 242.0925
# Epoch 193/500
# 336/336 [==============================] - 1s 3ms/step - loss: 241.6271
# Epoch 194/500
# 336/336 [==============================] - 1s 3ms/step - loss: 242.7032
# Epoch 195/500
# 336/336 [==============================] - 1s 3ms/step - loss: 241.9483
# Epoch 196/500
# 336/336 [==============================] - 1s 3ms/step - loss: 241.0083
# Epoch 197/500
# 336/336 [==============================] - 1s 3ms/step - loss: 242.0132
# Epoch 198/500
# 336/336 [==============================] - 1s 3ms/step - loss: 242.6820
# Epoch 199/500
# 336/336 [==============================] - 1s 3ms/step - loss: 241.4738
# Epoch 200/500
# 336/336 [==============================] - 1s 4ms/step - loss: 240.2033
# Epoch 201/500
# 336/336 [==============================] - 1s 3ms/step - loss: 243.6227
# Epoch 202/500
# 336/336 [==============================] - 1s 4ms/step - loss: 240.1339
# Epoch 203/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.0487
# Epoch 204/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.3190
# Epoch 205/500
# 336/336 [==============================] - 1s 3ms/step - loss: 242.2791
# Epoch 206/500
# 336/336 [==============================] - 1s 3ms/step - loss: 242.5768
# Epoch 207/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.0705
# Epoch 208/500
# 336/336 [==============================] - 1s 3ms/step - loss: 243.0084
# Epoch 209/500
# 336/336 [==============================] - 1s 3ms/step - loss: 242.0941
# Epoch 210/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.4524
# Epoch 211/500
# 336/336 [==============================] - 1s 3ms/step - loss: 241.4943
# Epoch 212/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.7077
# Epoch 213/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.1633
# Epoch 214/500
# 336/336 [==============================] - 1s 4ms/step - loss: 238.2788
# Epoch 215/500
# 336/336 [==============================] - 1s 3ms/step - loss: 239.9368
# Epoch 216/500
# 336/336 [==============================] - 1s 3ms/step - loss: 241.8946
# Epoch 217/500
# 336/336 [==============================] - 1s 3ms/step - loss: 239.6402
# Epoch 218/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.4831
# Epoch 219/500
# 336/336 [==============================] - 1s 3ms/step - loss: 243.2972
# Epoch 220/500
# 336/336 [==============================] - 1s 3ms/step - loss: 239.1234
# Epoch 221/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.7524
# Epoch 222/500
# 336/336 [==============================] - 1s 3ms/step - loss: 241.6155
# Epoch 223/500
# 336/336 [==============================] - 1s 3ms/step - loss: 238.8169
# Epoch 224/500
# 336/336 [==============================] - 1s 3ms/step - loss: 238.6102
# Epoch 225/500
# 336/336 [==============================] - 1s 3ms/step - loss: 239.4580
# Epoch 226/500
# 336/336 [==============================] - 1s 3ms/step - loss: 238.6840
# Epoch 227/500
# 336/336 [==============================] - 1s 3ms/step - loss: 241.9776
# Epoch 228/500
# 336/336 [==============================] - 1s 4ms/step - loss: 237.5007
# Epoch 229/500
# 336/336 [==============================] - 1s 3ms/step - loss: 239.3472
# Epoch 230/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.2312
# Epoch 231/500
# 336/336 [==============================] - 1s 3ms/step - loss: 237.9582
# Epoch 232/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.1086
# Epoch 233/500
# 336/336 [==============================] - 1s 3ms/step - loss: 238.7331
# Epoch 234/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.6746
# Epoch 235/500
# 336/336 [==============================] - 1s 3ms/step - loss: 238.3787
# Epoch 236/500
# 336/336 [==============================] - 1s 3ms/step - loss: 239.3406
# Epoch 237/500
# 336/336 [==============================] - 1s 3ms/step - loss: 243.5210
# Epoch 238/500
# 336/336 [==============================] - 1s 3ms/step - loss: 237.6020
# Epoch 239/500
# 336/336 [==============================] - 1s 4ms/step - loss: 237.4650
# Epoch 240/500
# 336/336 [==============================] - 1s 3ms/step - loss: 239.2625
# Epoch 241/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.6905
# Epoch 242/500
# 336/336 [==============================] - 1s 4ms/step - loss: 236.6201
# Epoch 243/500
# 336/336 [==============================] - 1s 3ms/step - loss: 241.4246
# Epoch 244/500
# 336/336 [==============================] - 1s 3ms/step - loss: 239.0501
# Epoch 245/500
# 336/336 [==============================] - 1s 3ms/step - loss: 236.6989
# Epoch 246/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.1033
# Epoch 247/500
# 336/336 [==============================] - 1s 3ms/step - loss: 237.0515
# Epoch 248/500
# 336/336 [==============================] - 1s 4ms/step - loss: 236.5037
# Epoch 249/500
# 336/336 [==============================] - 1s 3ms/step - loss: 237.6982
# Epoch 250/500
# 336/336 [==============================] - 1s 3ms/step - loss: 238.2301
# Epoch 251/500
# 336/336 [==============================] - 1s 3ms/step - loss: 236.5782
# Epoch 252/500
# 336/336 [==============================] - 1s 3ms/step - loss: 236.6457
# Epoch 253/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.2385
# Epoch 254/500
# 336/336 [==============================] - 1s 3ms/step - loss: 236.9663
# Epoch 255/500
# 336/336 [==============================] - 1s 3ms/step - loss: 237.5737
# Epoch 256/500
# 336/336 [==============================] - 1s 4ms/step - loss: 235.8069
# Epoch 257/500
# 336/336 [==============================] - 1s 3ms/step - loss: 241.3255
# Epoch 258/500
# 336/336 [==============================] - 1s 3ms/step - loss: 238.4302
# Epoch 259/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.7158
# Epoch 260/500
# 336/336 [==============================] - 1s 3ms/step - loss: 236.6577
# Epoch 261/500
# 336/336 [==============================] - 1s 3ms/step - loss: 236.6547
# Epoch 262/500
# 336/336 [==============================] - 1s 3ms/step - loss: 236.9681
# Epoch 263/500
# 336/336 [==============================] - 1s 3ms/step - loss: 236.5363
# Epoch 264/500
# 336/336 [==============================] - 1s 3ms/step - loss: 237.5842
# Epoch 265/500
# 336/336 [==============================] - 1s 3ms/step - loss: 236.1134
# Epoch 266/500
# 336/336 [==============================] - 1s 4ms/step - loss: 235.5474
# Epoch 267/500
# 336/336 [==============================] - 1s 3ms/step - loss: 238.6774
# Epoch 268/500
# 336/336 [==============================] - 1s 4ms/step - loss: 235.3751
# Epoch 269/500
# 336/336 [==============================] - 1s 3ms/step - loss: 238.0874
# Epoch 270/500
# 336/336 [==============================] - 1s 4ms/step - loss: 234.3075
# Epoch 271/500
# 336/336 [==============================] - 1s 3ms/step - loss: 236.2804
# Epoch 272/500
# 336/336 [==============================] - 1s 3ms/step - loss: 238.3350
# Epoch 273/500
# 336/336 [==============================] - 1s 3ms/step - loss: 235.6055
# Epoch 274/500
# 336/336 [==============================] - 1s 3ms/step - loss: 239.7922
# Epoch 275/500
# 336/336 [==============================] - 1s 3ms/step - loss: 238.6589
# Epoch 276/500
# 336/336 [==============================] - 1s 3ms/step - loss: 236.5212
# Epoch 277/500
# 336/336 [==============================] - 1s 4ms/step - loss: 234.2353
# Epoch 278/500
# 336/336 [==============================] - 1s 3ms/step - loss: 235.0096
# Epoch 279/500
# 336/336 [==============================] - 1s 3ms/step - loss: 234.5622
# Epoch 280/500
# 336/336 [==============================] - 1s 3ms/step - loss: 240.0413
# Epoch 281/500
# 336/336 [==============================] - 1s 3ms/step - loss: 234.9432
# Epoch 282/500
# 336/336 [==============================] - 1s 3ms/step - loss: 234.6775
# Epoch 283/500
# 336/336 [==============================] - 1s 3ms/step - loss: 235.5709
# Epoch 284/500
# 336/336 [==============================] - 1s 4ms/step - loss: 235.0451
# Epoch 285/500
# 336/336 [==============================] - 1s 3ms/step - loss: 236.5394
# Epoch 286/500
# 336/336 [==============================] - 1s 3ms/step - loss: 234.4927
# Epoch 287/500
# 336/336 [==============================] - 1s 4ms/step - loss: 235.2635
# Epoch 288/500
# 336/336 [==============================] - 1s 3ms/step - loss: 234.8190
# Epoch 289/500
# 336/336 [==============================] - 1s 3ms/step - loss: 234.3367
# Epoch 290/500
# 327/336 [============================>.] - ETA: 0s - loss: 236.5731Restoring model weights from the end of the best epoch.
# 336/336 [==============================] - 1s 3ms/step - loss: 234.9301
# Epoch 00290: early stopping
